# %% [markdown]
# # Import dependencies

# %%
import numpy as np
import pandas as pd
from pathlib import Path

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Import CSV files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a861fa1c-ecab-4623-b371-599e87af5c67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a861fa1c-ecab-4623-b371-599e87af5c67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2019loans.csv to 2019loans (10).csv

# %%
import io
train_df = pd.read_csv(io.BytesIO(uploaded['2019loans.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c1baece0-a5cd-4cf4-8ee1-d06a74c0e06f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1baece0-a5cd-4cf4-8ee1-d06a74c0e06f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020Q1loans.csv to 2020Q1loans (11).csv

# %%
import io
test_df = pd.read_csv(io.BytesIO(uploaded['2020Q1loans.csv']))
# Dataset is now stored in a Pandas Dataframe

# %% [markdown]
# # Verify Imported Data

# %%
test_df.count()
# Out:
# loan_amnt                     4702
# int_rate                      4702
# installment                   4702
# home_ownership                4702
# annual_inc                    4702
#                               ...
# total_bc_limit                4702
# total_il_high_credit_limit    4702
# hardship_flag                 4702
# debt_settlement_flag          4702
# target                        4702
# Length: 84, dtype: int64

# %%
train_df.count()
# Out:
# loan_amnt                     12180
# int_rate                      12180
# installment                   12180
# home_ownership                12180
# annual_inc                    12180
#                               ...
# total_bc_limit                12180
# total_il_high_credit_limit    12180
# hardship_flag                 12180
# debt_settlement_flag          12180
# target                        12180
# Length: 84, dtype: int64

# %% [markdown]
# Too much data for a visual verification

# %% [markdown]
# # Clean Data

# %% [markdown]
# Drop Null Rows and Columns if they exist

# %%
# Clean data to remove null columns and rows from test and train data
# Drop the null columns where all values are null

test_df = test_df.dropna(axis='columns', how='all')
train_df = train_df.dropna(axis='columns', how='all')


# Drop the null rows
test_df = test_df.dropna()
train_df = train_df.dropna()

# %%
# same count means there were not null rows or columns
test_df.count()
# Out:
# loan_amnt                     4702
# int_rate                      4702
# installment                   4702
# home_ownership                4702
# annual_inc                    4702
#                               ...
# total_bc_limit                4702
# total_il_high_credit_limit    4702
# hardship_flag                 4702
# debt_settlement_flag          4702
# target                        4702
# Length: 84, dtype: int64

# %%
# same count means there were not null rows or columns
train_df.count()
# Out:
# loan_amnt                     12180
# int_rate                      12180
# installment                   12180
# home_ownership                12180
# annual_inc                    12180
#                               ...
# total_bc_limit                12180
# total_il_high_credit_limit    12180
# hardship_flag                 12180
# debt_settlement_flag          12180
# target                        12180
# Length: 84, dtype: int64

# %% [markdown]
# The count of both datasets remained the same.  There must not have been any Null values in the data

# %%
test_df.head(10)
# Out:
#    loan_amnt  int_rate  ...  debt_settlement_flag    target
# 0    40000.0    0.1033  ...                     N  low_risk
# 1    24450.0    0.1430  ...                     N  low_risk
# 2    13500.0    0.1430  ...                     N  low_risk
# 3    10625.0    0.1774  ...                     N  low_risk
# 4     6375.0    0.1862  ...                     N  low_risk
# 5    15000.0    0.1102  ...                     N  low_risk
# 6    12000.0    0.0702  ...                     N  low_risk
# 7     4500.0    0.1308  ...                     N  low_risk
# 8     8000.0    0.1033  ...                     N  low_risk
# 9    40000.0    0.0646  ...                     N  low_risk
#
# [10 rows x 84 columns]

# %%
train_df.head(10)
# Out:
#    loan_amnt  int_rate  ...  debt_settlement_flag    target
# 0     7000.0    0.1894  ...                     N  low_risk
# 1    40000.0    0.1614  ...                     N  low_risk
# 2    11000.0    0.2055  ...                     N  low_risk
# 3     4000.0    0.1612  ...                     N  low_risk
# 4    14000.0    0.1797  ...                     N  low_risk
# 5     6000.0    0.0756  ...                     N  low_risk
# 6    10500.0    0.2250  ...                     N  low_risk
# 7    22000.0    0.0819  ...                     N  low_risk
# 8    10625.0    0.2055  ...                     N  low_risk
# 9    20000.0    0.2534  ...                     N  low_risk
#
# [10 rows x 84 columns]

# %% [markdown]
# # Find inconsistent data

# %%
train_df=pd.get_dummies(train_df)

# %%
test_df=pd.get_dummies(test_df)

# %%
# get number of columns to compare with test data
print(len(train_df.columns))
# Out:
# 94

# %%
# get number of columns to compare with train data
print(len(test_df.columns))
# Out:
# 93

# %% [markdown]
# The lengths are not the same, but which one is missing?

# %%
# put column names in dataframe
Train_Col = train_df.columns
Test_Col = test_df.columns

# %%
# added title to column
Train_Col =pd.DataFrame(Train_Col,columns=['labels'])
Test_Col =pd.DataFrame(Test_Col,columns=['labels'])

Train_Col
# Out:
#                     labels
# 0                loan_amnt
# 1                 int_rate
# 2              installment
# 3               annual_inc
# 4                      dti
# ..                     ...
# 89         hardship_flag_Y
# 90  debt_settlement_flag_N
# 91  debt_settlement_flag_Y
# 92        target_high_risk
# 93         target_low_risk
#
# [94 rows x 1 columns]

# %%
Test_Col
# Out:
#                     labels
# 0                loan_amnt
# 1                 int_rate
# 2              installment
# 3               annual_inc
# 4                      dti
# ..                     ...
# 88         hardship_flag_N
# 89         hardship_flag_Y
# 90  debt_settlement_flag_N
# 91        target_high_risk
# 92         target_low_risk
#
# [93 rows x 1 columns]

# %%
#convert data to strings
Train_Col.labels.apply(str)
Test_Col.labels.apply(str)
# Out:
# 0                  loan_amnt
# 1                   int_rate
# 2                installment
# 3                 annual_inc
# 4                        dti
#                ...
# 88           hardship_flag_N
# 89           hardship_flag_Y
# 90    debt_settlement_flag_N
# 91          target_high_risk
# 92           target_low_risk
# Name: labels, Length: 93, dtype: object

# %%
# Determine which data doesn't match
# "debt_settlement_flag_Y" is not in the Test dataset

Missing_Col = Train_Col.merge(Test_Col, how='left', indicator=True)
Missing_Col[Missing_Col['_merge'] == 'left_only'][['labels']]
# Out:
#                     labels
# 91  debt_settlement_flag_Y

# %% [markdown]
# Add this data to test data before analyzing data

# %% [markdown]
# # Import files again for analysis

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a82e160f-9564-41d1-9656-0b3d52743827" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a82e160f-9564-41d1-9656-0b3d52743827">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2019loans.csv to 2019loans (11).csv

# %%
import io
train_df = pd.read_csv(io.BytesIO(uploaded['2019loans.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5e174f24-1742-4de5-b71a-f321c0b84813" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e174f24-1742-4de5-b71a-f321c0b84813">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020Q1loans.csv to 2020Q1loans (12).csv

# %%
import io
test_df = pd.read_csv(io.BytesIO(uploaded['2020Q1loans.csv']))
# Dataset is now stored in a Pandas Dataframe

# %% [markdown]
# # Convert categorical data to numeric and separate target feature for training data

# %%
# reduced data size to only consider binary fields since logistic regression is better with smaller datasets

X_train = train_df.drop(['target'], axis=1)
X_train = pd.get_dummies(X_train, columns=["home_ownership","verification_status",
                                  "pymnt_plan","initial_list_status","debt_settlement_flag",
                                  "application_type","hardship_flag"], drop_first = True)

y_train = LabelEncoder().fit_transform(train_df['target'])

# %% [markdown]
# # Convert categorical data to numeric and separate target feature for testing data

# %%
# reduced data size to only consider binary fields

X_test = test_df.drop(['target'], axis=1)
X_test = pd.get_dummies(X_test, columns=["home_ownership","verification_status",
                                  "pymnt_plan","initial_list_status","debt_settlement_flag",
                                  "application_type","hardship_flag"], drop_first = True)

y_test = LabelEncoder().fit_transform(test_df['target'])

# %% [markdown]
# # Add missing dummy variables to testing set

# %%
# add missing variables to test dataset to avoid errors when analyzing

X_test['debt_settlement_flag_Y']=0
X_test.head()
# Out:
#    loan_amnt  int_rate  ...  hardship_flag_Y  debt_settlement_flag_Y
# 0    40000.0    0.1033  ...                1                       0
# 1    24450.0    0.1430  ...                0                       0
# 2    13500.0    0.1430  ...                1                       0
# 3    10625.0    0.1774  ...                0                       0
# 4     6375.0    0.1862  ...                0                       0
#
# [5 rows x 85 columns]

# %% [markdown]
# # Prediction - Which model you think will perform better?

# %%
#  I expect the Random Forest Classifier to yield a more accurate percentage than the Logistic regression model.  The Random 
# Forest classifier uses more decision trees when determining the probability.
# Out:
#   File "<ipython-input-1-2a8699d99a70>", line 1
#     I expect the Random Forest Classifier to yield a more accurate
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Train the Logistic Regression model on the unscaled data and print the model score

# %%
#logistic regression unscaled

classifier = LogisticRegression(max_iter=10000) 
classifier.fit(X_train, y_train) 
print(f"Training Data Score: {classifier.score(X_train, y_train)}") 
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.7025451559934318
# Testing Data Score: 0.5661420672054445

# %% [markdown]
# # Train a Random Forest Classifier model on unscaled data and print the model score

# %%
# Random Forest Classifer Unscaled
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.646958740961293

# %% [markdown]
# # Prediction - Which model you think will perform better?

# %%
#  I expect the Random Forest Classifier to yield a more accurate percentage than the Logistic regression model.  The Random 
# Forest classifier uses more decision trees when determining the probability.  Now that the data is scaled, the Logistic
# Regression model may perform better, but I still choose Random Forest Classifier

# %% [markdown]
# # Scale the data

# %%
# scaled data
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Train the Logistic Regression model on the scaled data and print the model score

# %%
#logistic regression scaled
classifier = LogisticRegression(max_iter=10000) 
classifier.fit(X_train_scaled, y_train) 
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}") 
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.7108374384236453
# Testing Data Score: 0.7279880901743939

# %% [markdown]
# # Train a Random Forest Classifier model on the scaled data and print the model score

# %%
# random forest classifer Scaled
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.6463207145895363

# %% [markdown]
# # Post Analysis

# %% [markdown]
# How do the model scores compare to each other?

# %%
# I would say there is a 8-10% difference in the accuracy of the unscaled data.  The Random Forest classifier was able to
# produce a more accurate predicion model than the Logistic Regression. # I would say there is a 10-12% difference in the accuracy of the scaled data.
# The Logistic Regression model was able to produce a more accurate predicion model than the Random Forest Classifier.

# %% [markdown]
# How do the model scores compare to the previous results on unscaled data?

# %%
# The Logistic Regression model on the scaled data improved its accuracy over 15%.  Where as the Random Forest Classifer's
# accuracy essentially stayed the same weathe the data is scaled or not.  Logistic regression models seem to perform more
# accurately with scaled data.

# %% [markdown]
# How does this compare to your prediction?

# %%
# I assumed the Random Forest Classifier would perform better because of the how it analyzes the data in comparison to the
# Logistic Regression model.  It seems that the Random Forest Classifier's accuracy wasn't affected by scaling the data.

# %%
# Convert categorical data to numeric and separate target feature for training data

# %%
# Convert categorical data to numeric and separate target feature for testing data

# %%
# add missing dummy variables to testing set

# %%
# Train the Logistic Regression model on the unscaled data and print the model score

# %%
# Train a Random Forest Classifier model and print the model score

# %%
# Scale the data

# %%
# Train the Logistic Regression model on the scaled data and print the model score

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
